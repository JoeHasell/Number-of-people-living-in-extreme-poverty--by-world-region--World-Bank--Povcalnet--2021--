# %%
import pandas as pd

# %%
msg = "Hi Joe"
print(msg)
# Out:
# Hi Joe

# %%
df = pd.read_csv('Data/Poverty and inequality measures from PovCal (2021).csv')

# %%
df
# Out:
#         Entity  Year  $1.90 per day - share of population below poverty line  \
# 0      Albania  1981                                           0.464528
# 1      Albania  1982                                           0.407918
# 2      Albania  1983                                           0.464528
# 3      Albania  1984                                           0.534846
# 4      Albania  1985                                           0.534846
# ...        ...   ...                                                ...
# 6990  Zimbabwe  2015                                          28.671930
# 6991  Zimbabwe  2016                                          32.366640
# 6992  Zimbabwe  2017                                          33.862690
# 6993  Zimbabwe  2018                                          33.216590
# 6994  Zimbabwe  2019                                          39.529950
#
#       $1.90 per day - poverty gap index  \
# 0                              0.000846
# ...

# %%
print(df.head())
# Out:
#     Entity  Year  $1.90 per day - share of population below poverty line  \
# 0  Albania  1981                                           0.464528
# 1  Albania  1982                                           0.407918
# 2  Albania  1983                                           0.464528
# 3  Albania  1984                                           0.534846
# 4  Albania  1985                                           0.534846
#
#    $1.90 per day - poverty gap index  \
# 0                           0.000846
# 1                           0.000816
# 2                           0.000854
# 3                           0.000987
# 4                           0.001000
#
#    $1.90 per day - total number of people below poverty line  \
# 0                                           12663.29
# 1                                           11357.58
# 2                                           13210.98
# 3                                           15534.22
# ...

# %%
df.head()
# Out:
#     Entity  Year  $1.90 per day - share of population below poverty line  \
# 0  Albania  1981                                           0.464528
# 1  Albania  1982                                           0.407918
# 2  Albania  1983                                           0.464528
# 3  Albania  1984                                           0.534846
# 4  Albania  1985                                           0.534846
#
#    $1.90 per day - poverty gap index  \
# 0                           0.000846
# 1                           0.000816
# 2                           0.000854
# 3                           0.000987
# 4                           0.001000
#
#    $1.90 per day - total number of people below poverty line  \
# 0                                           12663.29
# 1                                           11357.58
# 2                                           13210.98
# 3                                           15534.22
# ...

# %%
df.plot(x="Year", y="$1.90 per day - poverty gap index", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='$1.90 per day - poverty gap index'>

# %%
df.loc[df.Entity=="Albania"].plot(x="Year", y="$1.90 per day - poverty gap index", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='$1.90 per day - poverty gap index'>
